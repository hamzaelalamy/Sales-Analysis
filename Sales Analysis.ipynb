# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv('./Sales_Data/Sales_April_2019.csv')

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
files = [file for file in os.listdir('./Sales_Data')]
all_data = pd.DataFrame()

for file in files:
    df = pd.read_csv('./Sales_Data/'+file)
    all_data = pd.concat([all_data, df])
    
all_data.to_csv('all_months_data.csv',index=False)

# %%
all_data = pd.read_csv('all_months_data.csv')
all_data.head(10)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
# 6   176562        USB-C Charging Cable                1      11.95
# 7   176563  Bose SoundSport Headphones                1      99.99
# 8   176564        USB-C Charging Cable                1      11.95
# 9   176565          Macbook Pro Laptop                1       1700
#
#        Order Date                        Purchase Address
# 0  04/19/19 08:46            917 1st St, Dallas, TX 75001
# 1             NaN                                     NaN
# ...

# %%
all_data = all_data.dropna(how='all')
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
all_data = all_data[all_data['Order Date'].str[0:2]!='Or']
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data
# Out:
# C:\Users\El-alamy\AppData\Local\Temp\ipykernel_4592\4235809763.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month'] = all_data['Order Date'].str[0:2]
# C:\Users\El-alamy\AppData\Local\Temp\ipykernel_4592\4235809763.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month'] = all_data['Month'].astype('int32')
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# ...

# %%
all_data['Quantity Ordered'] = all_data['Quantity Ordered'].astype('int32')
all_data['Price Each'] = all_data['Price Each'].astype('float')
all_data["Sales"] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data
# Out:
# C:\Users\El-alamy\AppData\Local\Temp\ipykernel_4592\3626094814.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Quantity Ordered'] = all_data['Quantity Ordered'].astype('int32')
# C:\Users\El-alamy\AppData\Local\Temp\ipykernel_4592\3626094814.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Price Each'] = all_data['Price Each'].astype('float')
# C:\Users\El-alamy\AppData\Local\Temp\ipykernel_4592\3626094814.py:3: SettingWithCopyWarning:
# ...

# %%
res1=all_data.groupby('Month').sum()
res1['Sales']
# Out:
# Month
# 1     1822256.73
# 2     2202022.42
# 3     2807100.38
# 4     3390670.24
# 5     3152606.75
# 6     2577802.26
# 7     2647775.76
# 8     2244467.88
# 9     2097560.13
# 10    3736726.88
# 11    3199603.20
# 12    4613443.34
# Name: Sales, dtype: float64

# %%
months = range(1,13)
plt.bar(months,res1['Sales'])
plt.xticks(months)
plt.title("sales by month")
plt.xlabel("months")
plt.ylabel("Sales in $")
plt.show()

# %%
def get_city(adress):
    return adress.split(',')[1]
    
def get_state(adress):
    return adress.split(',')[2].split(' ')[1]

all_data["City"] = all_data["Purchase Address"].apply(lambda x : f"{get_city(x)} ({get_state(x)})")
all_data
# Out:
# C:\Users\El-alamy\AppData\Local\Temp\ipykernel_4592\3066719563.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data["City"] = all_data["Purchase Address"].apply(lambda x : f"{get_city(x)} ({get_state(x)})")
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...

# %%
res2 = all_data.groupby('City').sum()
res2
# Out:
#                      Quantity Ordered  Price Each   Month       Sales
# City
#  Atlanta (GA)                   16602  2779908.20  104794  2795498.58
#  Austin (TX)                    11153  1809873.61   69829  1819581.75
#  Boston (MA)                    22528  3637409.77  141112  3661642.01
#  Dallas (TX)                    16730  2752627.82  104620  2767975.40
#  Los Angeles (CA)               33289  5421435.23  208325  5452570.80
#  New York City (NY)             27932  4635370.83  175741  4664317.43
#  Portland (ME)                   2750   447189.25   17144   449758.27
#  Portland (OR)                  11303  1860558.22   70621  1870732.34
#  San Francisco (CA)             50239  8211461.74  315520  8262203.91
#  Seattle (WA)                   16553  2733296.01  104941  2747755.48

# %%
cities = [city for city ,df in all_data.groupby('City')]


plt.bar(cities,res2['Sales'])
plt.xticks(cities, rotation="vertical", size=8)
plt.title("sales by city")
plt.xlabel("cities")
plt.ylabel("Sales in $")
plt.show()

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])
all_data
# Out:
# C:\Users\El-alamy\AppData\Local\Temp\ipykernel_4592\1410441871.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# ...

# %%
all_data['Hour'] = all_data['Order Date'].dt.hour
all_data['Minute'] = all_data['Order Date'].dt.minute
all_data
# Out:
# C:\Users\El-alamy\AppData\Local\Temp\ipykernel_4592\2543858614.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Hour'] = all_data['Order Date'].dt.hour
# C:\Users\El-alamy\AppData\Local\Temp\ipykernel_4592\2543858614.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Minute'] = all_data['Order Date'].dt.minute
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# ...

# %%
hours = [hour for hour, df in all_data.groupby('Hour')]

plt.plot(hours, all_data.groupby('Hour').count())
plt.xticks(hours)
plt.xlabel('Hours')
plt.ylabel('number of orders')
plt.grid()
plt.show()

# %%
minutes = [minute for minute, df in all_data.groupby('Minute')]

plt.plot(minutes, all_data.groupby('Minute').count())
plt.xticks(minutes, size=5)
plt.xlabel('minutes')
plt.ylabel('Sales in $')
plt.grid()
plt.show()

# %%
df = all_data[all_data['Order ID'].duplicated(keep=False)]
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))
df = df[['Order ID', 'Grouped']].drop_duplicates()
df.head()
# Out:
# C:\Users\El-alamy\AppData\Local\Temp\ipykernel_4592\3207136778.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))
#     Order ID                                            Grouped
# 3     176560                      Google Phone,Wired Headphones
# 18    176574                  Google Phone,USB-C Charging Cable
# 30    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32    176586                AAA Batteries (4-pack),Google Phone
# 119   176672      Lightning Charging Cable,USB-C Charging Cable

# %%
from itertools import combinations
from collections import Counter

count = Counter()
for row in df['Grouped']:
    row_list = row.split(",")
    count.update(Counter(combinations(row_list,2)))

for key, value in count.most_common(10):
    print(key,value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %%
group_counts = df['Grouped'].value_counts()
group_counts
# Out:
# iPhone,Lightning Charging Cable                                            882
# Google Phone,USB-C Charging Cable                                          856
# iPhone,Wired Headphones                                                    361
# Vareebadd Phone,USB-C Charging Cable                                       312
# Google Phone,Wired Headphones                                              303
#                                                                           ...
# Google Phone,USB-C Charging Cable,Wired Headphones,USB-C Charging Cable      1
# 34in Ultrawide Monitor,LG Washing Machine                                    1
# 20in Monitor,iPhone                                                          1
# Google Phone,USB-C Charging Cable,Wired Headphones,27in FHD Monitor          1
# LG Washing Machine,AA Batteries (4-pack)                                     1
# Name: Grouped, Length: 366, dtype: int64

# %%
product_group = all_data.groupby("Product")
quantity = product_group.sum()["Quantity Ordered"]

products = [product for product, df in product_group]

plt.bar(products, quantity)
plt.xticks(products, rotation = "vertical",size=8)
plt.xlabel('products')
plt.ylabel('Quantity Ordered')
plt.show()

# %%
# Group by 'Product' and calculate the maximum price for each product
prices = all_data.groupby("Product")["Price Each"].max()

# Group by 'Product' and sum the quantity ordered for each product
quantity = all_data.groupby("Product")["Quantity Ordered"].sum()

products = prices.index

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.bar(products, quantity, color='b', alpha=0.7, label='Quantity Ordered')

ax2.plot(products, prices, color='r', marker='o', label='Prices')

ax1.set_xlabel("Products")
ax1.set_ylabel("Quantity Ordered", color='b')
ax2.set_ylabel("Prices", color='r')

ax1.set_xticks(range(len(products)))
ax1.set_xticklabels(products, rotation="vertical", fontsize=8)

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()
